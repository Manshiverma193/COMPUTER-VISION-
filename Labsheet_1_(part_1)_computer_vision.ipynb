# %% [markdown]
# LABSHEET= 1 (PART 1)
# NAME = MASNHI VERMA
# CUID = CU24250193
# ROLL NO. = 30
# SUBJECT = COMPUTER VISION

# %% [markdown]
# 1.Write a programm to read , display and write an image using openCV in python.

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Read the image
image = cv2.imread("/content/images.jpg")

# Check whether image was read successfully
if image is None:
    print("Image not found. Please check the file path.")
else:
    # Display the image
    cv2_imshow(image)

    # Write/Save the image
    cv2.imwrite("output.jpg", image)

    print("Image displayed and saved successfully.")
        # Display new size
    print("30:",20 , "x", 10)
    print("Image displayed and saved successfully.")
# Out:
# <PIL.Image.Image image mode=RGB size=547x365>
# Image displayed and saved successfully.
# 30: 20 x 10
# Image displayed and saved successfully.

# %% [markdown]
# 2. Write a program to Convert a color image into Grayscale and Binary Image

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get image filename
filename = next(iter(uploaded))
print("Image Name:", filename)

# Read the color image
image = cv2.imread(filename)

# Convert color image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Convert grayscale image to binary image
_, binary_image = cv2.threshold(gray_image, 100, 255, cv2.THRESH_BINARY)

# Display original color image
print("Original Color Image:")
cv2_imshow(image)

# Display grayscale image
print("Grayscale Image:")
cv2_imshow(gray_image)

# Display binary image
print("Binary Image:")
cv2_imshow(binary_image)

# Save images
cv2.imwrite("grayscale.jpg", gray_image)
cv2.imwrite("binary.jpg", binary_image)

print("Grayscale and Binary images saved successfully.")
# Out:
#      <input type="file" id="files-79b9ca25-f698-458f-9023-f73494142902" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79b9ca25-f698-458f-9023-f73494142902">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 3.Write a Program to compute and Display the complement(Negative) of an Image.

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get image filename
filename = next(iter(uploaded))

# Read the original color image
image = cv2.imread(filename)

# Convert color image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Compute complement (negative) of color image
negative_color = 255 - image

# Compute complement (negative) of grayscale image
negative_gray = 255 - gray_image

# Display Original Color Image
print("Original Color Image:")
cv2_imshow(image)

# Display Grayscale Image
print("Grayscale Image:")
cv2_imshow(gray_image)

# Display Negative Color Image
print("Negative (Complement) Color Image:")
cv2_imshow(negative_color)

# Display Negative Grayscale Image
print("Negative (Complement) Grayscale Image:")
cv2_imshow(negative_gray)
# Out:
#      <input type="file" id="files-5a99f644-2c7a-4747-9679-d2a18c149b87" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a99f644-2c7a-4747-9679-d2a18c149b87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 4.Write a Program to Resize ,Crop and display an image

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get image filename
filename = next(iter(uploaded))

# Read the image
image = cv2.imread(filename)

# Display original image
print("Original Image:")
cv2_imshow(image)

# Resize the image
resized_image = cv2.resize(image, (300, 300))

print("Resized Image:")
cv2_imshow(resized_image)

# Crop the image
# Format: image[y1:y2, x1:x2]
cropped_image = image[50:300, 50:300]

print("Cropped Image:")
cv2_imshow(cropped_image)
# Out:
#      <input type="file" id="files-a3746c46-08d8-4ff6-85cf-7bc707b7eb76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3746c46-08d8-4ff6-85cf-7bc707b7eb76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 5.Write a Python program using OpenCV to split an image into two parts and merge the parts back into the original image

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()
filename = next(iter(uploaded))

# Read image
image = cv2.imread(filename)

# Get image dimensions
height, width = image.shape[:2]

# Split image into two parts
part1 = image[:, :width//2]
part2 = image[:, width//2:]

# Display split images
print("First Part:")
cv2_imshow(part1)

print("Second Part:")
cv2_imshow(part2)

# Merge the two parts
merged_image = cv2.hconcat([part1, part2])

# Display merged image
print("Merged Image:")
cv2_imshow(merged_image)

# Save merged image
cv2.imwrite("merged.jpg", merged_image)
# Out:
#      <input type="file" id="files-3dbe89b6-41d5-44fd-90e5-a3b0cab9a41f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dbe89b6-41d5-44fd-90e5-a3b0cab9a41f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
